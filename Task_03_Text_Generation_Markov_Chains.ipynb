# %%
import random
from collections import defaultdict

# Step 1: Training text (you can modify this)
training_text = """
Artificial intelligence is the future of technology.
Artificial intelligence helps humans solve complex problems.
Machine learning is a part of artificial intelligence.
Deep learning is a subset of machine learning.
"""

# Step 2: Preprocess text
words = training_text.lower().split()

# Step 3: Build Markov Chain
markov_chain = defaultdict(list)

for i in range(len(words) - 1):
    current_word = words[i]
    next_word = words[i + 1]
    markov_chain[current_word].append(next_word)

# Step 4: Generate text
def generate_text(start_word, length=20):
    current_word = start_word.lower()
    generated_text = [current_word]

    for _ in range(length):
        next_words = markov_chain.get(current_word)
        if not next_words:
            break
        current_word = random.choice(next_words)
        generated_text.append(current_word)

    return " ".join(generated_text)

# Step 5: Run text generation
output = generate_text("artificial", 25)
print("Generated Text:\n")
print(output)
# Out:
# Generated Text:
#
# artificial intelligence. deep learning is the future of technology. artificial intelligence helps humans solve complex problems. machine learning is a part of machine learning.
